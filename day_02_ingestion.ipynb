# %%
# Cell 1 — Setup
import duckdb
import sys
sys.path.append(r"C:\Users\User\Desktop\bootcamp\labs\m5-project-weather-pipeline\src")

from ingestion import ingest_all_weather, ingest_cotton
from config import DB_PATH

con = duckdb.connect(DB_PATH)

# %%
# Cell 2 — Ingest cotton
cotton = ingest_cotton(con)
cotton.head()
# Out:
# [2026-04-24 00:01:12] =======================================================
# [2026-04-24 00:01:12] STEP 2 — Cotton Dataset Ingestion
# [2026-04-24 00:01:12] =======================================================
# [2026-04-24 00:01:12]   Raw shape after reshape: (725, 3)
# [2026-04-24 00:01:12]   Nulls in yield:          0
# [2026-04-24 00:01:12]   Districts:               29
# [2026-04-24 00:01:12]   Years:                   2000 – 2024
# [2026-04-24 00:01:12]
#   raw_cotton table created in DuckDB
#             region  year yield_tonnes
# 0  Agdash district  2000          6.9
# 1  Agdash district  2001          9.3
# 2  Agdash district  2002         19.8
# 3  Agdash district  2003         14.5
# 4  Agdash district  2004         14.4

# %%
# Cell 3 — Fetch weather
weather = ingest_all_weather(con)
weather.head()
# Out:
# [2026-04-24 00:01:13] =======================================================
# [2026-04-24 00:01:13] STEP 1 — Weather Ingestion
# [2026-04-24 00:01:13] =======================================================
# [2026-04-24 00:01:13]   Fetching weather for Ganja (2000–2024)...
# [2026-04-24 00:01:16]     Saved 9132 rows → C:\Users\User\Desktop\bootcamp\labs\m5-project-weather-pipeline\data\raw\weather\ganja_daily.csv
# [2026-04-24 00:01:16]   Fetching weather for Shamkir (2000–2024)...
# [2026-04-24 00:01:16]     Saved 9132 rows → C:\Users\User\Desktop\bootcamp\labs\m5-project-weather-pipeline\data\raw\weather\shamkir_daily.csv
# [2026-04-24 00:01:16]   Fetching weather for Sabirabad (2000–2024)...
# ---------------------------------------------------------------------------
# OpenMeteoRequestsError                    Traceback (most recent call last)
# ...

# %%
# Cell 4 — Verify
print("Cotton shape:", cotton.shape)
print("Weather shape:", weather.shape)
print("Nulls in cotton:", cotton.isnull().sum().sum())
print("Nulls in weather:", weather.isnull().sum().sum())
